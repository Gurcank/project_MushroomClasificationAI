# %% [markdown]
# # Mushroom Toxicity Classification EDA
#
# This notebook explores the UCI Mushroom Dataset for binary classification.
#
# Target mapping: `e = 0` (edible), `p = 1` (poisonous).

# %%
import pandas as pd

df = pd.read_csv('data/mushrooms.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.isna().sum().sort_values(ascending=False).head(10)

# %%
df['class'].value_counts()
